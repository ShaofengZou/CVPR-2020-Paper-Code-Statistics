# %%
import pandas as pd
import requests
from tqdm import tqdm
from bs4 import BeautifulSoup
from unidecode import unidecode
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from multiprocessing import Pool
import tqdm
import os
import re

year = '2020'
proxy = 10809 # need change to your proxy for searching on google scholar
os.makedirs('info', exist_ok=True)

def get_score(row):
    score = row.stars if not row.stars == '' else 0
    if len(row['github']) > 0:
        score += 0.5
    return score

def get_paper_info():
    print('Getting paper info...')
    info = {}
    base_url = 'http://openaccess.thecvf.com/CVPR%s.py' % year
    soup = BeautifulSoup(requests.get(base_url).content, "html.parser")
    for a in tqdm.tqdm(soup.find_all('a')):
        link = a.get('href')
        if link is None or link[-5:] != '.html':
            continue
        link = "http://openaccess.thecvf.com/{}".format(a.get('href'))
        paper = BeautifulSoup(requests.get(link).content, "html.parser")
        title = unidecode(paper.find('div', {'id': 'papertitle'}).text.lstrip())
        authors = unidecode(paper.find('i').text).split(',  ')
        abstract = unidecode(paper.find('div', {'id': 'abstract'}).text.strip())
        info[title.lower()] = {'authors': authors, 'abstract': abstract, 'title': title}
    return info

def get_row(row):
    return {'author': row['authors'][0],
        'github': row['github'] if 'github' in row else '',
        'stars': row['stars'] if 'stars' in row else '',
        'task 1': row['tasks'][0] if 'stars' in row and row['tasks'][0] is not None else '',
        'task 2': row['tasks'][1] if 'stars' in row and row['tasks'][1] is not None else '',
        'task 3': row['tasks'][2] if 'stars' in row and row['tasks'][2] is not None else '',
        'title': row['title'],
        }


def get_github(rowi):
    row = info[rowi]
    # print(row)
    url = 'https://paperswithcode.com/search?q={}'.format(row['title'].replace(' ', '+'))
    results = BeautifulSoup(requests.get(url).content, 'html.parser')
    has_code = []
    for res in results.find_all('div', {'class': 'infinite-item'}):
        link = res.find('a', {'class': 'badge-dark'})
        if unidecode(link.text.strip()) == 'Code':
            has_code.append('https://paperswithcode.com{}'.format(link.get('href')))
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform([row['abstract']]).A
    Y = []
    papers = []
    tasks = np.empty(5, dtype=object)
    for link in has_code:
        paper = BeautifulSoup(requests.get(link).content, 'html.parser')
        papers.append(paper)
        paperabs = unidecode(paper.find('div', {'class': 'paper-abstract'}).find('p').text.strip().replace('\n', ' ').replace('...', ' ').replace(' (read more)', ''))
        Y.append(paperabs)

        results = paper.find('div', {'class': 'col-md-5 paper-section'}).find('div', {'class': 'paper-section-title'}).find('div', {'class': 'paper-tasks'}).find_all('ul', {'class':'list-unstyled'})
        for idx, tmp in enumerate(results):
            task = tmp.find('a').get('href').split('/')[-1]
            tasks[idx] = task

    if len(Y) > 0:
        Y = vectorizer.transform(Y).A
        scores = np.matmul(Y, X.T)[:,0]
        best_ix = np.argmax(scores)
        if scores[best_ix] > .85:
            paper = papers[best_ix]
            code = paper.find('div', {'class': 'paper-implementations'}).find('div', {'class': 'row'})
            github = code.find('a', {'class': 'code-table-link'}).get('href')
            stars = int(unidecode(code.find_all('div', {'class': 'paper-impl-cell'})[1].text).strip().replace(' ', '').replace(',', ''))
            return rowi, {'github': github, 'stars': stars, 'tasks': tasks}
 
    return rowi, {}

def get_scholar(rowi):
    row = info[rowi]   
    
    proxies = {"http": "http://127.0.0.1:{}/".format(proxy), "https": "http://127.0.0.1:{}/".format(proxy)}
    url = 'https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q={}'.format(row['title'].replace(' ', '+'))
    content = requests.get(url, proxies=proxies).content.decode('latin-1')
    search_reference_rates = re.findall('Cited by .*?</a>', content, re.MULTILINE)
    reference_rates = []
    for search_reference_rate in search_reference_rates:
        if search_reference_rate:
            search_reference_rate_id_start = 9
            search_reference_rate_id_end = search_reference_rate.find('<')
            reference_rate = search_reference_rate[search_reference_rate_id_start:search_reference_rate_id_end]
            print('reference_rate:', reference_rate)
            reference_rates.append(reference_rate)
    return rowi, {'reference_rate': reference_rates}

# %% [markdown]
# ## Step 1. Get paper information

# %%
paper_info_filename = os.path.join('cache', 'CVPR%s_paper_info.npy' % year)
try:
    info = np.load(paper_info_filename, allow_pickle=True).tolist()
    print('Load paper information for CVPR %s successfully' % year)
except:
    info = get_paper_info()
    np.save(paper_info_filename, info)
    print('Save paper information for CVPR %s successfully' % year)
# Out:
# Load paper information for CVPR 2020 successfully

# %% [markdown]
# ## Step 2. Get github information

# %%
print('Getting github info...')
github_info_filename = os.path.join('cache', 'CVPR%s_github_info.npy' % year)
try:
    github_info = np.load(github_info_filename, allow_pickle=True).tolist()
    print('Load github information for CVPR %s successfully' % year)
except:
    github_info = {}
#     tmp = list(info.keys())[:20]
    for key in tqdm.tqdm(info.keys()):
        try:
            row, single_info = get_github(key)
            github_info[row] = single_info
        except:
            print('Failed in paper:', key)
    np.save(github_info_filename, github_info)
    print('Save github information for CVPR %s successfully' % year)
# Out:
# Getting github info...
# Load github information for CVPR 2020 successfully

# %%
for k, val in github_info.items():
    info[k].update(val)

# %% [markdown]
# ## Step 3. Save to csv files

# %%
list(info.items())[0]
# Out:
# ('unsupervised learning of probably symmetric deformable 3d objects from images in the wild',
#  {'authors': ['Shangzhe Wu', 'Christian Rupprecht', 'Andrea Vedaldi'],
#   'abstract': 'We propose a method to learn 3D deformable object categories from raw single-view images, without external supervision. The method is based on an autoencoder that factors each input image into depth, albedo, viewpoint and illumination. In order to disentangle these components without supervision, we use the fact that many object categories have, at least in principle, a symmetric structure. We show that reasoning about illumination allows us to exploit the underlying object symmetry even if the appearance is not symmetric due to shading. Furthermore, we model objects that are probably, but not certainly, symmetric by predicting a symmetry probability map, learned end-to-end with the other components of the model. Our experiments show that this method can recover very accurately the 3D shape of human faces, cat faces and cars from single-view images, without any supervision or a prior shape model. On benchmarks, we demonstrate superior accuracy compared to another method that uses supervision at the level of 2D image correspondences.',
#   'title': 'Unsupervised Learning of Probably Symmetric Deformable 3D Objects From Images in the Wild',
#   'github': 'https://github.com/elliottwu/unsup3d',
#   'stars': 504,
#   'tasks': array([None, None, None, None, None], dtype=object)})

# %%
info_result = map(get_row, info.values())
df = pd.DataFrame(info_result)
df['score'] = df.apply(get_score, axis=1)
df = df.sort_values(['score', 'github'], ascending=False)
df = df[['title', 'author', 'task 1', 'task 2', 'task 3', 'github', 'stars']]
df.index = range(1, len(df) + 1)
outname = os.path.join('info', 'CVPR%s_info.csv' % year)
print('Saving to ', outname)
df.to_csv(outname)
# Out:
# Saving to  info\CVPR2020_info.csv

# %%
df
# Out:
#                                                   title              author  \
# 1     Context R-CNN: Long Term Temporal Context for ...          Sara Beery
# 2     MnasFPN: Learning Latency-Aware Pyramid Archit...             Bo Chen
# 3     Google Landmarks Dataset v2 - A Large-Scale Be...       Tobias Weyand
# 4            PointRend: Image Segmentation As Rendering  Alexander Kirillov
# 5     Distilling Effective Supervision From Severe L...        Zizhao Zhang
# ...                                                 ...                 ...
# 1463  RetinaTrack: Online Single Stage Joint Detecti...          Zhichao Lu
# 1464  Multimodal Categorization of Crisis Events in ...     Mahdi Abavisani
# 1465     SwapText: Image Based Texts Transfer in Scenes      Qiangpeng Yang
# 1466  OrigamiNet: Weakly-Supervised, Segmentation-Fr...      Mohamed Yousef
# 1467               FroDO: From Detections to 3D Objects         Martin Runz
#
#                      task 1               task 2 task 3  \
# 1          object-detection  video-understanding
# 2          object-detection
# 3           image-retrieval    transfer-learning
# 4     semantic-segmentation
# 5      image-classification
# ...                     ...                  ...    ...
# 1463
# 1464
# 1465
# 1466
# 1467
#
#                                                  github  stars
# 1     https://github.com/tensorflow/models/tree/mast...  64576
# 2     https://github.com/tensorflow/models/tree/mast...  64576
# 3     https://github.com/tensorflow/models/tree/mast...  64576
# 4     https://github.com/facebookresearch/detectron2...  11147
# 5     https://github.com/google-research/google-rese...  10588
# ...                                                 ...    ...
# 1463
# 1464
# 1465
# 1466
# 1467
#
# [1467 rows x 7 columns]

# %% [markdown]
# ## 4. Topics anaysis

# %%
topics_list = df['task 1'].tolist() + df['task 2'].tolist() + df['task 3'].tolist()
all_topics= set(topics_list)
all_topics
# Out:
# {'',
#  '3d-absolute-human-pose-estimation',
#  '3d-face-reconstruction',
#  '3d-human-action-recognition',
#  '3d-human-pose-estimation',
#  '3d-instance-segmentation-1',
#  '3d-multi-object-tracking',
#  '3d-object-classification',
#  '3d-object-detection',
#  '3d-object-detection-from-stereo-images',
#  '3d-object-reconstruction',
#  '3d-object-reconstruction-from-a-single-image',
#  '3d-pose-estimation',
#  '3d-reconstruction',
#  '3d-semantic-instance-segmentation',
#  '3d-semantic-segmentation',
#  '3d-shape-analysis',
#  '3d-shape-recognition',
#  '3d-shape-reconstruction',
#  '3d-shape-representation',
#  '3d-shape-retrieval',
#  '6d-pose-estimation',
#  '6d-pose-estimation-1',
#  'action-classification',
#  'action-detection',
#  'action-localization',
#  'action-recognition',
#  'action-recognition-in-videos',
#  'action-segmentation',
#  'action-spotting',
#  'active-learning',
#  'adversarial-attack',
#  'adversarial-defense',
#  'anomaly-detection',
#  'architecture-search',
#  'autonomous-driving',
#  'autonomous-navigation',
#  'autonomous-vehicles',
#  'bilevel-optimization',
#  'bird-view-synthesis',
#  'blind-image-deblurring',
#  'blind-image-quality-assessment',
#  'brain-segmentation',
#  'calibration',
#  'camera-relocalization',
#  'causal-discovery',
#  'color-constancy',
#  'colorization',
#  'combinatorial-optimization',
#  'community-detection',
#  'compositional-zero-shot-learning',
#  'compressive-sensing',
#  'conditional-image-generation',
#  'connectivity-estimation',
#  'continual-learning',
#  'contrastive-learning',
#  'cross-modal-retrieval',
#  'cross-view-image-to-image-translation',
#  'data-augmentation',
#  'deblurring',
#  'deep-attention',
#  'deepfake-detection',
#  'demosaicking',
#  'denoising',
#  'dense-object-detection',
#  'density-estimation',
#  'depth-completion',
#  'depth-estimation',
#  'dictionary-learning',
#  'dimensionality-reduction',
#  'disparity-estimation',
#  'domain-adaptation',
#  'domain-generalization',
#  'edge-detection',
#  'face-alignment',
#  'face-anti-spoofing',
#  'face-clustering',
#  'face-detection',
#  'face-generation',
#  'face-hallucination',
#  'face-recognition',
#  'face-reconstruction',
#  'face-swapping',
#  'facial-expression-recognition',
#  'feature-selection',
#  'few-shot-image-classification',
#  'few-shot-image-segmentation',
#  'few-shot-learning',
#  'few-shot-object-detection',
#  'fine-grained-image-classification',
#  'fine-grained-vehicle-classification',
#  'fine-grained-visual-recognition',
#  'gaussian-processes',
#  'gaze-estimation',
#  'gesture-recognition',
#  'graph-construction',
#  'graph-embedding',
#  'graph-generation',
#  'graph-matching',
#  'hand-gesture-recognition',
#  'hand-segmentation',
#  'handwriting-recognition',
#  'homography-estimation',
#  'human-detection',
#  'human-motion-prediction',
#  'human-object-interaction-detection',
#  'human-parsing',
#  'image-augmentation',
#  'image-captioning',
#  'image-classification',
#  'image-compression',
#  'image-deconvolution',
#  'image-denoising',
#  'image-enhancement',
#  'image-forensics',
#  'image-generation',
#  'image-inpainting',
#  'image-manipulation-detection',
#  'image-matting',
#  'image-morphing',
#  'image-quality-assessment',
#  'image-reconstruction',
#  'image-registration',
#  'image-restoration',
#  'image-retrieval',
#  'image-super-resolution',
#  'image-to-image-translation',
#  'imitation-learning',
#  'imputation',
#  'instance-segmentation',
#  'interactive-segmentation',
#  'interest-point-detection',
#  'keypoint-detection',
#  'language-modelling',
#  'latent-variable-models',
#  'layout-to-image-generation',
#  'line-segment-detection',
#  'lip-reading',
#  'lip-to-speech-synthesis',
#  'lipreading',
#  'low-light-image-enhancement',
#  'machine-translation',
#  'meta-learning',
#  'metric-learning',
#  'model-compression',
#  'model-selection',
#  'monocular-3d-object-detection',
#  'monocular-depth-estimation',
#  'monocular-visual-odometry',
#  'motion-capture',
#  'motion-compensation',
#  'motion-estimation',
#  'motion-prediction',
#  'multi-object-tracking',
#  'multi-person-pose-estimation',
#  'multi-task-learning',
#  'multimodal-unsupervised-image-to-image',
#  'multiple-instance-learning',
#  'multiple-object-tracking',
#  'multiple-people-tracking',
#  'network-pruning',
#  'neural-network-compression',
#  'no-reference-image-quality-assessment',
#  'node-classification',
#  'novel-view-synthesis',
#  'object-classification',
#  'object-detection',
#  'object-detection-in-aerial-images',
#  'object-localization',
#  'object-recognition',
#  'object-reconstruction',
#  'object-tracking',
#  'one-class-classifier',
#  'open-set-learning',
#  'optical-character-recognition',
#  'optical-flow-estimation',
#  'out-of-distribution-detection',
#  'panoptic-segmentation',
#  'pedestrian-detection',
#  'person-identification',
#  'person-re-identification',
#  'person-search',
#  'point-cloud-registration',
#  'pose-estimation',
#  'pose-prediction',
#  'pose-transfer',
#  'quantization',
#  'question-answering',
#  'rain-removal',
#  'real-time-instance-segmentation',
#  'real-time-semantic-segmentation',
#  'region-proposal',
#  'relational-reasoning',
#  'representation-learning',
#  'robust-speech-recognition',
#  'saliency-detection',
#  'salient-object-detection',
#  'scene-flow-estimation',
#  'scene-graph-generation',
#  'scene-parsing',
#  'scene-recognition',
#  'scene-segmentation',
#  'scene-text',
#  'scene-text-detection',
#  'scene-text-editing',
#  'scene-text-recognition',
#  'scene-understanding',
#  'self-driving-cars',
#  'self-supervised-action-recognition',
#  'self-supervised-image-classification',
#  'self-supervised-learning',
#  'semantic-segmentation',
#  'semantic-similarity',
#  'semi-supervised-semantic-segmentation',
#  'semi-supervised-video-object-segmentation',
#  'shadow-detection',
#  'shape-from-texture',
#  'sign-language-recognition',
#  'sign-language-translation',
#  'single-image-deraining',
#  'single-view-3d-reconstruction',
#  'skeleton-based-action-recognition',
#  'sketch-based-image-retrieval',
#  'spatio-temporal-action-localization',
#  'speaker-specific-lip-to-speech-synthesis',
#  'speech-dereverberation',
#  'speech-enhancement',
#  'speech-recognition',
#  'steganographics',
#  'stereo-matching-1',
#  'stochastic-optimization',
#  'structured-prediction',
#  'style-transfer',
#  'super-resolution',
#  'synthetic-data-generation',
#  'task-194',
#  'temporal-action-proposal-generation',
#  'text-generation',
#  'text-matching',
#  'text-spotting',
#  'texture-synthesis',
#  'time-series',
#  'time-series-classification',
#  'traffic-sign-recognition',
#  'trajectory-prediction',
#  'transfer-learning',
#  'unsupervised-domain-adaptation',
#  'unsupervised-image-to-image-translation',
#  'unsupervised-person-re-identification',
#  'video-captioning',
#  'video-classification',
#  'video-compression',
#  'video-denoising',
#  'video-frame-interpolation',
#  'video-object-detection',
#  'video-object-segmentation',
#  'video-prediction',
#  'video-question-answering',
#  'video-recognition',
#  'video-retrieval',
#  'video-semantic-segmentation',
#  'video-super-resolution',
#  'video-understanding',
#  'virtual-try-on',
#  'visual-dialogue',
#  'visual-navigation',
#  'visual-object-tracking',
#  'visual-odometry',
#  'visual-question-answering',
#  'visual-reasoning',
#  'visual-tracking',
#  'weakly-supervised-action-localization',
#  'weakly-supervised-object-detection',
#  'weakly-supervised-semantic-segmentation',
#  'zero-shot-learning'}

# %%
from collections import Counter
import matplotlib.pyplot as plt
keyword_counter = Counter(topics_list)

# %%
topic_count = pd.DataFrame([(ele, keyword_counter[ele]) for ele in keyword_counter], columns=['topic', 'count']).sort_values(by=['count'], ascending=False)
topic_count.to_csv(os.path.join('info', 'CVPR%s_topic_count.csv' % year))
topic_count
# Out:
#                                      topic  count
# 8                                            3443
# 0                         object-detection     57
# 2                    semantic-segmentation     49
# 3                     image-classification     32
# 4                         image-generation     26
# ..                                     ...    ...
# 156                  action-classification      1
# 154                       video-captioning      1
# 152                    community-detection      1
# 146                        color-constancy      1
# 274  unsupervised-person-re-identification      1
#
# [275 rows x 2 columns]

# %%
keyword_counter['image-super-resolution']
# Out:
# 9

# %%
# Show N most common keywords and their frequencies
num_keyowrd = 75
keywords_counter_vis = keyword_counter.most_common(num_keyowrd)

plt.rcdefaults()
fig, ax = plt.subplots(figsize=(8, num_keyowrd//5), dpi=144)

key = [k[0] for k in keywords_counter_vis] 
value = [k[1] for k in keywords_counter_vis] 
y_pos = np.arange(len(key))
ax.barh(y_pos, value, align='center', color='green', ecolor='black', log=True)
ax.set_yticks(y_pos)
ax.set_yticklabels(key, rotation=0, fontsize=10)
ax.invert_yaxis() 
for i, v in enumerate(value):
    ax.text(v + 3, i + .25, str(v), color='black', fontsize=10)
# ax.text(y_pos, value, str(value))
ax.set_xlabel('Frequency')
ax.set_title('CVPR %s Submission Top %d Topics' % (year, num_keyowrd))

plt.savefig(os.path.join('info', '/CVPR%s_topics.png' % year), bbox_inches='tight', pad_inches=0)
plt.show()

# %%
# Show the word cloud forming by keywords
from wordcloud import WordCloud
wordcloud = WordCloud(max_font_size=64, max_words=160, 
                      width=1280, height=640,
                      background_color="black").generate(' '.join(topics_list))
plt.figure(figsize=(16, 8), dpi=144)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.savefig(os.path.join('info', 'CVPR%s_wordcloud.png' % year), bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# ## Search papers according to keyword and topic

# %%
def pull_papers(paper_infos, topic, search_range='all'):
    target_title = paper_infos[paper_infos['title'].str.contains(topic.capitalize())]

    target_topic = pd.DataFrame()
    for i in range(3):
        tmp = paper_infos[paper_infos['task %d' % (i+1)].str.contains(topic)]
        target_topic = pd.concat([target_topic, tmp]).drop_duplicates()

    if search_range == 'title':
        return target_title
    elif search_range == 'topic':
        return target_topic
    elif search_range == 'all':
        return pd.concat([target_title, target_topic]).drop_duplicates()

# %%
pull_papers(df, 'denoising')
# Out:
#                                                   title  \
# 127   FastDVDnet: Towards Real-Time Deep Video Denoi...
# 172   A Physics-Based Noise Formation Model for Extr...
# 238   Supervised Raw Video Denoising With a Benchmar...
# 339   Transfer Learning From Synthetic to Real-Noise...
# 684   Event Probability Mask (EPM) and Event Denoisi...
# 693   Self2Self With Dropout: Learning Self-Supervis...
# 721   Joint Demosaicing and Denoising With Self Guid...
# 804   Memory-Efficient Hierarchical Neural Architect...
# 1285  Basis Prediction Networks for Effective Burst ...
# 130   CycleISP: Real Image Restoration via Improved ...
# 270   Show, Edit and Tell: A Framework for Editing I...
# 434   Plug-and-Play Algorithms for Large-Scale Snaps...
# 492   Enhancing Intrinsic Adversarial Robustness via...
# 93    Rethinking Data Augmentation for Image Super-r...
# 511        ColorFool: Semantic Adversarial Colorization
#
#                      author              task 1               task 2  \
# 127          Matias Tassano           denoising  motion-compensation
# 172             Kaixuan Wei           denoising      image-denoising
# 238            Huanjing Yue           denoising      image-denoising
# 339             Yoonsik Kim           denoising    transfer-learning
# 684          R. Wes Baldwin
# 693              Yuhui Quan
# 721                 Lin Liu
# 804            Haokui Zhang
# 1285             Zhihao Xia
# 130        Syed Waqas Zamir           denoising      image-denoising
# 270           Fawaz Sammani           denoising     image-captioning
# 434                Xin Yuan           denoising
# 492              Guanlin Li           denoising    image-restoration
# 93               Jaejun Yoo   data-augmentation            denoising
# 511   Ali Shahin Shamsabadi  adversarial-attack         colorization
#
#                         task 3  \
# 127          motion-estimation
# 172
# 238            video-denoising
# 339
# 684
# 693
# 721
# 804
# 1285
# 130          image-restoration
# 270
# 434
# 492   self-supervised-learning
# 93           image-restoration
# 511                  denoising
#
#                                                  github stars
# 127             https://github.com/m-tassano/fastdvdnet   102
# 172            https://github.com/Vandermode/NoiseModel    75
# 238                https://github.com/cao-cong/RViDeNet    49
# 339                  https://github.com/terryoo/AINDNet    25
# 684
# 693
# 721
# 804
# 1285
# 130                   https://github.com/swz30/CycleISP    98
# 270      https://github.com/fawazsammani/show-edit-tell    40
# 434                https://github.com/liuyang12/PnP-SCI    11
# 492   https://github.com/GuanlinLee/FPD-for-Adversar...     6
# 93                   https://github.com/clovaai/cutblur   157
# 511           https://github.com/smartcameras/ColorFool     4
